# %%
import pandas as pd
df = pd.read_csv('.\data\ielts.csv')
df.head()
# Out:
#    Unnamed: 0                                                  0  \
# 0           0  https://writing9.com/text/661010d3143b1d001153...
# 1           1  https://writing9.com/text/65fa6000d33bac0011fe...
# 2           2  https://writing9.com/text/65f2ecd3ecea9d0011e7...
# 3           3  https://writing9.com/text/65e726b139714a001162...
# 4           4  https://writing9.com/text/65e4cc9739714a001162...
#
#                                                    1  \
# 0  Some university students want to learn about o...
# 1  The use of cell phones (mobile phones) has gro...
# 2  Nowadays, many medical research projects are f...
# 3  Some people think that governments should ban ...
# 4  News editors decide what to broadcast on telev...
#
#                                                    2  \
# 0  #university\n#students\n#subjects\n#addition\n...
# 1         #cell\n#phones\n#years\n#people\n#business
# 2  #research\n#projects\n#companies\n#individuals...
# ...
